# %%
import pandas as pd
oo = pd.read_csv('E:\learn\learn\python\olympic.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
type(oo.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oo.index[100]
# Out:
# 100

# %%
oo.index[5]
# Out:
# 5

# %%
oo.set_index('Athlete')
# Out:
#                                 City  Edition      Sport       Discipline  \
# Athlete
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# HERSCHMANN, Otto              Athens     1896   Aquatics         Swimming
# DRIVAS, Dimitrios             Athens     1896   Aquatics         Swimming
# MALOKINIS, Ioannis            Athens     1896   Aquatics         Swimming
# CHASAPIS, Spiridon            Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# ANDREOU, Joannis              Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# NEUMANN, Paul                 Athens     1896   Aquatics         Swimming
# PEPANOS, Antonios             Athens     1896   Aquatics         Swimming
# ...

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete',inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace=False)
# Out:
#                            Athlete     City  Edition      Sport  \
# 0                    HAJOS, Alfred   Athens     1896   Aquatics
# 1                 HERSCHMANN, Otto   Athens     1896   Aquatics
# 2                DRIVAS, Dimitrios   Athens     1896   Aquatics
# 3               MALOKINIS, Ioannis   Athens     1896   Aquatics
# 4               CHASAPIS, Spiridon   Athens     1896   Aquatics
# 5            CHOROPHAS, Efstathios   Athens     1896   Aquatics
# 6                    HAJOS, Alfred   Athens     1896   Aquatics
# 7                 ANDREOU, Joannis   Athens     1896   Aquatics
# 8            CHOROPHAS, Efstathios   Athens     1896   Aquatics
# 9                    NEUMANN, Paul   Athens     1896   Aquatics
# 10               PEPANOS, Antonios   Athens     1896   Aquatics
# 11                   LANE, Francis   Athens     1896  Athletics
# 12                SZOKOLYI, Alajos   Athens     1896  Athletics
# 13                   BURKE, Thomas   Athens     1896  Athletics
# ...

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath = oo.set_index("Athlete")

# %%
ath.reset_index(inplace=False)
# Out:
#                            Athlete     City  Edition      Sport  \
# 0                    HAJOS, Alfred   Athens     1896   Aquatics
# 1                 HERSCHMANN, Otto   Athens     1896   Aquatics
# 2                DRIVAS, Dimitrios   Athens     1896   Aquatics
# 3               MALOKINIS, Ioannis   Athens     1896   Aquatics
# 4               CHASAPIS, Spiridon   Athens     1896   Aquatics
# 5            CHOROPHAS, Efstathios   Athens     1896   Aquatics
# 6                    HAJOS, Alfred   Athens     1896   Aquatics
# 7                 ANDREOU, Joannis   Athens     1896   Aquatics
# 8            CHOROPHAS, Efstathios   Athens     1896   Aquatics
# 9                    NEUMANN, Paul   Athens     1896   Aquatics
# 10               PEPANOS, Antonios   Athens     1896   Aquatics
# 11                   LANE, Francis   Athens     1896  Athletics
# 12                SZOKOLYI, Alajos   Athens     1896  Athletics
# 13                   BURKE, Thomas   Athens     1896  Athletics
# ...

# %%
ath.reset_index(inplace=True)

# %%
ath
# Out:
#                            Athlete     City  Edition      Sport  \
# 0                    HAJOS, Alfred   Athens     1896   Aquatics
# 1                 HERSCHMANN, Otto   Athens     1896   Aquatics
# 2                DRIVAS, Dimitrios   Athens     1896   Aquatics
# 3               MALOKINIS, Ioannis   Athens     1896   Aquatics
# 4               CHASAPIS, Spiridon   Athens     1896   Aquatics
# 5            CHOROPHAS, Efstathios   Athens     1896   Aquatics
# 6                    HAJOS, Alfred   Athens     1896   Aquatics
# 7                 ANDREOU, Joannis   Athens     1896   Aquatics
# 8            CHOROPHAS, Efstathios   Athens     1896   Aquatics
# 9                    NEUMANN, Paul   Athens     1896   Aquatics
# 10               PEPANOS, Antonios   Athens     1896   Aquatics
# 11                   LANE, Francis   Athens     1896  Athletics
# 12                SZOKOLYI, Alajos   Athens     1896  Athletics
# 13                   BURKE, Thomas   Athens     1896  Athletics
# ...

# %%
ath.set_index('Athlete',inplace=True)

# %%
ath.sort_index(inplace=True,ascending=False)

# %%
oo.set_index('Athlete',inplace=True)

# %%
oo.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
oo.iloc[[1700,3499,34]]
# Out:
#                      City  Edition       Sport   Discipline  NOC Gender  \
# Athlete
# RABOT, Pierre      London     1908     Sailing      Sailing  FRA    Men
# JONSSON, Sven O.  Antwerp     1920  Gymnastics  Artistic G.  SWE    Men
# GARRETT, Robert    Athens     1896   Athletics    Athletics  USA    Men
#
#                                  Event Event_gender   Medal
# Athlete
# RABOT, Pierre                       6m            X  Bronze
# JONSSON, Sven O.  team, Swedish system            M    Gold
# GARRETT, Robert              long jump            M  Silver

# %%
oo.iloc[100:120]
# Out:
#                             City  Edition       Sport   Discipline  NOC  \
# Athlete
# FLATOW, Alfred            Athens     1896  Gymnastics  Artistic G.  GER
# FLATOW, Gustav Felix      Athens     1896  Gymnastics  Artistic G.  GER
# HILMAR, Georg             Athens     1896  Gymnastics  Artistic G.  GER
# HOFMANN, Fritz            Athens     1896  Gymnastics  Artistic G.  GER
# MANTEUFFEL, Fritz         Athens     1896  Gymnastics  Artistic G.  GER
# NEUKIRCH, Karl            Athens     1896  Gymnastics  Artistic G.  GER
# RÖSTEL, Richard           Athens     1896  Gymnastics  Artistic G.  GER
# SCHUFT, Gustav            Athens     1896  Gymnastics  Artistic G.  GER
# SCHUMANN, Carl            Athens     1896  Gymnastics  Artistic G.  GER
# WEINGÄRTNER, Hermann      Athens     1896  Gymnastics  Artistic G.  GER
# ANDRIAKOPOULOS, Nicolaos  Athens     1896  Gymnastics  Artistic G.  GRE
# ATHANASOPOULOS, Spyros    Athens     1896  Gymnastics  Artistic G.  GRE
# ...

# %%
oo.groupby('Edition')

# %%
type(oo.groupby('Edition'))
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
for group_key, group_value in oo.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#                                City  Edition          Sport       Discipline  \
# Athlete
# HAJOS, Alfred                Athens     1896       Aquatics         Swimming
# HERSCHMANN, Otto             Athens     1896       Aquatics         Swimming
# DRIVAS, Dimitrios            Athens     1896       Aquatics         Swimming
# MALOKINIS, Ioannis           Athens     1896       Aquatics         Swimming
# CHASAPIS, Spiridon           Athens     1896       Aquatics         Swimming
# CHOROPHAS, Efstathios        Athens     1896       Aquatics         Swimming
# HAJOS, Alfred                Athens     1896       Aquatics         Swimming
# ANDREOU, Joannis             Athens     1896       Aquatics         Swimming
# CHOROPHAS, Efstathios        Athens     1896       Aquatics         Swimming
# NEUMANN, Paul                Athens     1896       Aquatics         Swimming
# PEPANOS, Antonios            Athens     1896       Aquatics         Swimming
# ...

# %%
type(group_key)
# Out:
# int

# %%
oo.groupby(['Edition','City']).agg(['count','min'])
# Out:
#                               Sport           Discipline                NOC  \
#                               count       min      count          min count
# Edition City
# 1896    Athens                  151  Aquatics        151  Artistic G.   151
# 1900    Paris                   512  Aquatics        512      Archery   512
# 1904    St Louis                470  Aquatics        470      Archery   470
# 1908    London                  804  Aquatics        804      Archery   804
# 1912    Stockholm               885  Aquatics        885  Artistic G.   885
# 1920    Antwerp                1298  Aquatics       1298      Archery  1298
# 1924    Paris                   884  Aquatics        884  Artistic G.   884
# 1928    Amsterdam               710  Aquatics        710  Artistic G.   710
# 1932    Los Angeles             615  Aquatics        615  Artistic G.   615
# 1936    Berlin                  875  Aquatics        875  Artistic G.   875
# ...

# %%
oo[(oo.Edition == 2000)& ((oo.Event == '100m'))]
# Out:
#                        City  Edition      Sport Discipline  NOC Gender Event  \
# Athlete
# THOMPSON, Obadele    Sydney     2000  Athletics  Athletics  BAR    Men  100m
# GREENE, Maurice      Sydney     2000  Athletics  Athletics  USA    Men  100m
# BOLDON, Ato          Sydney     2000  Athletics  Athletics  TRI    Men  100m
# OTTEY-PAGE, Merlene  Sydney     2000  Athletics  Athletics  JAM  Women  100m
# LAWRENCE, Tanya      Sydney     2000  Athletics  Athletics  JAM  Women  100m
# THANOU, Ekaterini    Sydney     2000  Athletics  Athletics  GRE  Women  100m
#
#                     Event_gender   Medal
# Athlete
# THOMPSON, Obadele              M  Bronze
# GREENE, Maurice                M    Gold
# BOLDON, Ato                    M  Silver
# OTTEY-PAGE, Merlene            W  Bronze
# LAWRENCE, Tanya                W  Silver
# THANOU, Ekaterini              W  Silver
